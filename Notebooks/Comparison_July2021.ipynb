# %%
from source2 import *

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Of all variables the STD on the CNR seems to be doing the worse. This I believe is because the std is taken all values, including the negatives, and computing the std. Note how when the deep blue color (and those the maximun of the negative values) is max the STD of the cnr marks the height of the PBL at that heigth. Since the CNR values are in dB, the negative values

# %% [markdown]
# ## July 17

# %%
path0 = "/Users/jenifervivar/Desktop/NERTO_2022/LIDAR_JUN17-30_2021/FXD20210717/"
variables = VAREXTRACT(path0)

variables.extract()
cnr_17 = variables.cnr_day
time_17 = pd.to_datetime(variables.time_day, unit = 's', utc = True)

#create Data frame

july17_cnr = dataframe_set(cnr_17, time_17, "2021-07-17")

   
july17_cnrmean = pbl_height(july17_cnr, stat = "mean")
july17_cnrstd = pbl_height(july17_cnr)
july17_cnrmedian = pbl_height(july17_cnr, stat = "median")


#Getting liDAR derived values for PBL

pbl_17 = variables.atm_structures
df_structures_17 = dataframe_set(pbl_17, time_17, "2021-07-17")
lidar_pbl17 = pbl_lidar(df_structures_17)

#lidar_pbl17 = lidar_pbl17[lidar_pbl17.index.date ==pd.Timestamp("2021-07-17").date()]

windsp_17 = variables.ver_wind_speed
df_wind = dataframe_set(windsp_17, time_17, "2021-07-17")

plot_all(july17_cnr,lidar_pbl17,july17_cnrmean, july17_cnrstd,july17_cnrmedian, "July 17, 2021")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [3], in <cell line: 13>()
#       8 #create Data frame
#      10 july17_cnr = dataframe_set(cnr_17, time_17, "2021-07-17")
# ---> 13 july17_cnrmean = pbl_height(july17_cnr, stat = "mean")
#      14 july17_cnrstd = pbl_height(july17_cnr)
#      15 july17_cnrmedian = pbl_height(july17_cnr, stat = "median")
#
# File ~/Documents/GitHub/NOAA_PBLH/Notebooks/source2.py:58, in pbl_height(df, stat, var_type)
#      47 def pbl_height(df, stat="std", var_type=None):
#      49     """
#      50     input:
#      51     This functions takes a dataframe with dates as index, and the statistic of interest you want o calculate per hour.
#    (...)
#      56
#      57     """
# ---> 58     std_series = pbl_height_sub(df, stat, var_type)
#      59     # std_series = std_series.transpose()
#      60     rval = []
#
# ...

# %% [markdown]
# ## July 19

# %%
path1 = "/Users/jenifervivar/Desktop/NERTO_2022/LIDAR_JUN17-30_2021/FXD20210719/"
variables = VAREXTRACT(path1)

variables.extract()
cnr_19 = variables.cnr_day
time_19 = pd.to_datetime(variables.time_day, unit = 's', utc = True)

#create Data frame

july19_cnr = dataframe_set(cnr_19, time_19, "2021-07-19")


july19_cnrmean = pbl_heigth(july19_cnr, stat = "mean")
july19_cnrstd = pbl_heigth(july19_cnr)
july19_cnrmedian = pbl_heigth(july19_cnr, stat = "median")


#Getting liDAR derived values for PBL

pbl_19 = variables.atm_structures
df_structures_19 = dataframe_set(pbl_19, time_19, "2021-07-19")
lidar_pbl19 = pbl_lidar(df_structures_19)

#lidar_pbl17 = lidar_pbl17[lidar_pbl17.index.date ==pd.Timestamp("2021-07-17").date()]

windsp_19 = variables.ver_wind_speed
df_wind = dataframe_set(windsp_19, time_19, "2021-07-19")
plot_all(july19_cnr,lidar_pbl19,july19_cnrmean, july19_cnrstd,july19_cnrmedian, "July 19, 2021")

# %% [markdown]
# ## July 22

# %%
path2 = "/Users/jenifervivar/Desktop/NERTO_2022/LIDAR_JUN17-30_2021/FXD20210722/"
variables = VAREXTRACT(path2)

variables.extract()
cnr_19 = variables.cnr_day
time_19 = pd.to_datetime(variables.time_day, unit = 's', utc = True)

#create Data frame
date = "2021-07-22"
july19_cnr = dataframe_set(cnr_19, time_19, date)


july19_cnrmean = pbl_heigth(july19_cnr, stat = "mean")
july19_cnrstd = pbl_heigth(july19_cnr)
july19_cnrmedian = pbl_heigth(july19_cnr, stat = "median")


#Getting liDAR derived values for PBL

pbl_19 = variables.atm_structures
df_structures_19 = dataframe_set(pbl_19, time_19, date)
lidar_pbl19 = pbl_lidar(df_structures_19)

#lidar_pbl17 = lidar_pbl17[lidar_pbl17.index.date ==pd.Timestamp("2021-07-17").date()]

windsp_19 = variables.ver_wind_speed
df_wind = dataframe_set(windsp_19, time_19,date)
plot_all(july19_cnr,lidar_pbl19,july19_cnrmean, july19_cnrstd,july19_cnrmedian, date)

# %% [markdown]
# ## July 24

# %%
path3 = "/Users/jenifervivar/Desktop/NERTO_2022/LIDAR_JUN17-30_2021/FXD20210724/"
variables = VAREXTRACT(path4)

variables.extract()
cnr_19 = variables.cnr_day
time_19 = pd.to_datetime(variables.time_day, unit = 's', utc = True)

#create Data frame
date = "2021-07-24"
july19_cnr = dataframe_set(cnr_19, time_19, date)


july19_cnrmean = pbl_heigth(july19_cnr, stat = "mean")
july19_cnrstd = pbl_heigth(july19_cnr)
july19_cnrmedian = pbl_heigth(july19_cnr, stat = "median")


#Getting liDAR derived values for PBL

pbl_19 = variables.atm_structures
df_structures_19 = dataframe_set(pbl_19, time_19, date)
lidar_pbl19 = pbl_lidar(df_structures_19)

#lidar_pbl17 = lidar_pbl17[lidar_pbl17.index.date ==pd.Timestamp("2021-07-17").date()]

windsp_19 = variables.ver_wind_speed
df_wind = dataframe_set(windsp_19, time_19,date)
plot_all(july19_cnr,lidar_pbl19,july19_cnrmean, july19_cnrstd,july19_cnrmedian, date)

# %% [markdown]
# ## July 26

# %%
path4 = "/Users/jenifervivar/Desktop/NERTO_2022/LIDAR_JUN17-30_2021/FXD20210726/"
variables = VAREXTRACT(path4)

variables.extract()
cnr_19 = variables.cnr_day
time_19 = pd.to_datetime(variables.time_day, unit = 's', utc = True)

#create Data frame
date = "2021-07-26"
july19_cnr = dataframe_set(cnr_19, time_19, date)


july19_cnrmean = pbl_heigth(july19_cnr, stat = "mean")
july19_cnrstd = pbl_heigth(july19_cnr)
july19_cnrmedian = pbl_heigth(july19_cnr, stat = "median")


#Getting liDAR derived values for PBL

pbl_19 = variables.atm_structures
df_structures_19 = dataframe_set(pbl_19, time_19, date)
lidar_pbl19 = pbl_lidar(df_structures_19)

#lidar_pbl17 = lidar_pbl17[lidar_pbl17.index.date ==pd.Timestamp("2021-07-17").date()]

windsp_19 = variables.ver_wind_speed
df_wind = dataframe_set(windsp_19, time_19,date)
plot_all(july19_cnr,lidar_pbl19,july19_cnrmean, july19_cnrstd,july19_cnrmedian, date)

# %% [markdown]
# ## July 27

# %%
path5 = "/Users/jenifervivar/Desktop/NERTO_2022/LIDAR_JUN17-30_2021/FXD20210727/"
variables = VAREXTRACT(path5)

variables.extract()
cnr_19 = variables.cnr_day
time_19 = pd.to_datetime(variables.time_day, unit = 's', utc = True)

#create Data frame
date = "2021-07-27"
july19_cnr = dataframe_set(cnr_19, time_19, date)


july19_cnrmean = pbl_heigth(july19_cnr, stat = "mean")
july19_cnrstd = pbl_heigth(july19_cnr)
july19_cnrmedian = pbl_heigth(july19_cnr, stat = "median")


#Getting liDAR derived values for PBL

pbl_19 = variables.atm_structures
df_structures_19 = dataframe_set(pbl_19, time_19, date)
lidar_pbl19 = pbl_lidar(df_structures_19)

#lidar_pbl17 = lidar_pbl17[lidar_pbl17.index.date ==pd.Timestamp("2021-07-17").date()]

windsp_19 = variables.ver_wind_speed
df_wind = dataframe_set(windsp_19, time_19,date)
plot_all(july19_cnr,lidar_pbl19,july19_cnrmean, july19_cnrstd,july19_cnrmedian, date)

# %%
def plot_all(df_cnr = None, df_lidar= None,df_wrf = None, tup_mean = None, tup_std = None, tup_median= None, date = ""):
    import matplotlib.pyplot as plt
    import numpy as np
    
    fig, ax =plt.subplots(figsize = (10,10))
    pcnr= df_cnr.transpose()
    pcnr.index = pcnr.index.astype(int)
    pcnr.columns = pcnr.columns.hour
    
    CS = plt.contourf(pcnr.columns, np.flip(pcnr.index.values),np.flip(pcnr.values), cmap= "seismic")
    cbar = fig.colorbar(CS)
    cbar.ax.set_ylabel('CNR (dB)')

    plt.plot(tup_mean[0].hour, tup_mean[1], label = "CNR-mean derived Values", color = "lime")
    plt.plot(tup_std[0].hour, tup_std[1], label = "CNR-STD derived Values", color = "deeppink")
    plt.plot(tup_median[0].hour, tup_median[1], label = "CNR-Median derived Values", color = "darkorange")
    plt.plot(df_wrf.date.hour, df_wrf.MixHgt, label = "WRF Mixing Heigth Values", color = "black")
    plt.plot(df_lidar.index.hour,df_lidar, label = "LiDAR Values", color = "yellow")
    plt.title("PBL Calculations for "+ date)
    plt.ylabel("Heigth (m)")
    plt.xlabel("Time (UTC)")
    plt.legend()
    plt.gcf()
    plt.show()
