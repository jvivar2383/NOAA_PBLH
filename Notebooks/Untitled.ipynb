# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import seaborn as sns

# %%
p = '/Users/jenifervivar/Desktop/NERTO_2022/EXTRA_DATA/wrf_vmixingoutput.csv'
df = pd.read_csv(p)
df.head(-5)
# Out:
#      Unnamed: 0                 date PSQ   MixHgt   10xKz      U*   Zo  Zterr  \
# 0             0  2021-07-17 00:00:00   D   203.60   279.2  0.2194  0.2  13.88
# 1             1  2021-07-17 01:00:00   D   109.60   123.3  0.1511  0.2  13.88
# 2             2  2021-07-17 02:00:00   D    91.29   115.7  0.1322  0.2  13.88
# 3             3  2021-07-17 03:00:00   D    70.05   127.8  0.1346  0.2  13.89
# 4             4  2021-07-17 04:00:00   D    70.67   111.2  0.1298  0.2  13.88
# ..          ...                  ...  ..      ...     ...     ...  ...    ...
# 312          13  2021-07-30 13:00:00   B   342.30  1017.0  0.5362  0.2  13.78
# 313          14  2021-07-30 14:00:00   A   692.50  1462.0  0.6596  0.2  13.76
# 314          15  2021-07-30 15:00:00   A   903.70  1925.0  0.7706  0.2  13.74
# 315          16  2021-07-30 16:00:00   A  1215.00  2156.0  0.8126  0.2  13.73
# 316          17  2021-07-30 17:00:00   A  1835.00  1884.0  0.8080  0.2  13.73
#
#           Kh  10mWSPD  ...  RH2m   T02m  Density    Cld    u10m    v10m  \
# 0     1077.0   1.0640  ...   0.0  303.6    1.152 -100.0  0.7556  0.7492
# 1      301.9   0.6020  ...   0.0  302.9    1.154 -100.0  0.5142  0.3131
# 2      274.0   0.5782  ...   0.0  302.0    1.157 -100.0  0.2751  0.5086
# 3      298.3   0.6292  ...   0.0  301.0    1.161 -100.0  0.1070  0.6201
# 4      208.8   0.5446  ...   0.0  300.4    1.163 -100.0  0.3310  0.4325
# ..       ...      ...  ...   ...    ...      ...    ...     ...     ...
# 312   4566.0   3.6350  ...   0.0  297.4    1.172 -100.0  2.5670 -2.5740
# 313  10200.0   4.3940  ...   0.0  298.7    1.167 -100.0  3.1340 -3.0800
# 314  15110.0   5.0430  ...   0.0  299.9    1.163 -100.0  3.7560 -3.3650
# 315  20640.0   5.2060  ...   0.0  300.6    1.160 -100.0  4.0090 -3.3210
# 316  20600.0   5.5340  ...   0.0  301.3    1.156 -100.0  4.4370 -3.3070
#
#       WDIR  latitude  longitude   met
# 0    225.2      40.7     -73.93  AWRF
# 1    238.7      40.7     -73.93  AWRF
# 2    208.4      40.7     -73.93  AWRF
# 3    189.8      40.7     -73.93  AWRF
# 4    217.4      40.7     -73.93  AWRF
# ..     ...       ...        ...   ...
# 312  315.1      40.7     -73.93  AWRF
# 313  314.5      40.7     -73.93  AWRF
# 314  311.9      40.7     -73.93  AWRF
# 315  309.6      40.7     -73.93  AWRF
# 316  306.7      40.7     -73.93  AWRF
#
# [317 rows x 22 columns]
